# %% [markdown]
# <a href="https://colab.research.google.com/github/mjiii25/prac_class/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
library(tidyverse)
# Out:
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
# ── Attaching packages ─────────────────────────────────────── tidyverse 1.3.0 ──
#
# ✔ ggplot2 3.3.3     ✔ purrr   0.3.4
# ✔ tibble  3.1.0     ✔ dplyr   1.0.5
# ✔ tidyr   1.1.3     ✔ stringr 1.4.0
# ✔ readr   1.4.0     ✔ forcats 0.5.1
#
# ── Conflicts ────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()

# %% [markdown]
# # R practice using 'nycflights13' data

# %%
install.packages("nycflights13")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(nycflights13)

# %%
flights[1:5,]
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
#   time_hour
# 1 2013-01-01 05:00:00
# 2 2013-01-01 05:00:00
# 3 2013-01-01 05:00:00
# 4 2013-01-01 05:00:00
# 5 2013-01-01 06:00:00

# %% [markdown]
# ## filter()
# #### : filter data

# %%
filter(flights, month == 10, day  == 25) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 10    25   13      2359           14        401      350
# 2 2013 10    25  455       500           -5        649      648
# 3 2013 10    25  511       517           -6        756      757
# 4 2013 10    25  539       545           -6        924      933
# 5 2013 10    25  545       545            0        825      827
# 6 2013 10    25  546       545            1        845      855
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       B6       745   N653JB  JFK    PSE  205      1617     23   59
# 2   1       US      1843   N181UW  EWR    CLT  100       529      5    0
# 3  -1       UA       252   N580UA  EWR    IAH  196      1400      5   17
# 4  -9       B6      1403   N637JB  JFK    SJU  205      1598      5   45
# 5  -2       UA      1714   N24706  LGA    IAH  192      1416      5   45
# ...

# %%
filter(flights, month == 10, day == 25) %>% filter(dep_time < 500) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 10    25   13      2359           14        401      350
# 2 2013 10    25  455       500           -5        649      648
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 11        B6       745   N653JB  JFK    PSE  205      1617     23   59
# 2  1        US      1843   N181UW  EWR    CLT  100       529      5    0
#   time_hour
# 1 2013-10-25 23:00:00
# 2 2013-10-25 05:00:00

# %% [markdown]
# ## arrange()
# ### : arrange data. descending option

# %%
arrange(flights, year, month, day) %>% head()
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     1   517      515             2         830      819
# 2 2013 1     1   533      529             4         850      830
# 3 2013 1     1   542      540             2         923      850
# 4 2013 1     1   544      545            -1        1004     1022
# 5 2013 1     1   554      600            -6         812      837
# 6 2013 1     1   554      558            -4         740      728
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1  11       UA      1545   N14228  EWR    IAH  227      1400     5    15
# 2  20       UA      1714   N24211  LGA    IAH  227      1416     5    29
# 3  33       AA      1141   N619AA  JFK    MIA  160      1089     5    40
# 4 -18       B6       725   N804JB  JFK    BQN  183      1576     5    45
# 5 -25       DL       461   N668DN  LGA    ATL  116       762     6     0
# ...

# %%
arrange(flights, year, month, desc(day)) %>% head() #descending order
# Out:
#   year month day dep_time sched_dep_time dep_delay arr_time sched_arr_time
# 1 2013 1     31   1       2100           181       124      2225
# 2 2013 1     31   4       2359             5       455       444
# 3 2013 1     31   7       2359             8       453       437
# 4 2013 1     31  12       2250            82       132         7
# 5 2013 1     31  26       2154           152       328        50
# 6 2013 1     31  34       2159           155       135      2315
#   arr_delay carrier flight tailnum origin dest air_time distance hour minute
# 1 179       WN       530   N550WN  LGA    MDW  127       725     21    0
# 2  11       B6       739   N599JB  JFK    PSE  206      1617     23   59
# 3  16       B6       727   N505JB  JFK    BQN  197      1576     23   59
# 4  85       B6        30   N178JB  JFK    ROC   60       264     22   50
# 5 158       B6       515   N663JB  EWR    FLL  161      1065     21   54
# ...

# %% [markdown]
# ## select()
# #### : select columns

# %%
select(flights, year, month, day) %>% head()
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %%
select(flights, year : day) %>% head() #using :
# Out:
#   year month day
# 1 2013 1     1
# 2 2013 1     1
# 3 2013 1     1
# 4 2013 1     1
# 5 2013 1     1
# 6 2013 1     1

# %%
select(flights, -(year : day)) %>% head() #excluding the data
# Out:
#   dep_time sched_dep_time dep_delay arr_time sched_arr_time arr_delay carrier
# 1 517      515             2         830      819            11       UA
# 2 533      529             4         850      830            20       UA
# 3 542      540             2         923      850            33       AA
# 4 544      545            -1        1004     1022           -18       B6
# 5 554      600            -6         812      837           -25       DL
# 6 554      558            -4         740      728            12       UA
#   flight tailnum origin dest air_time distance hour minute time_hour
# 1 1545   N14228  EWR    IAH  227      1400     5    15     2013-01-01 05:00:00
# 2 1714   N24211  LGA    IAH  227      1416     5    29     2013-01-01 05:00:00
# 3 1141   N619AA  JFK    MIA  160      1089     5    40     2013-01-01 05:00:00
# 4  725   N804JB  JFK    BQN  183      1576     5    45     2013-01-01 05:00:00
# ...

# %% [markdown]
# ## mutate()
# #### : add new variables

# %%
flights %>% select(year : day, ends_with("delay"), distance, air_time) %>% head()
# Out:
#   year month day dep_delay arr_delay distance air_time
# 1 2013 1     1    2         11       1400     227
# 2 2013 1     1    4         20       1416     227
# 3 2013 1     1    2         33       1089     160
# 4 2013 1     1   -1        -18       1576     183
# 5 2013 1     1   -6        -25        762     116
# 6 2013 1     1   -4         12        719     150

# %%
flights %>%
      select( year : day , ends_with("delay"), distance, air_time) %>%
      mutate(gain = dep_delay - arr_delay,
              hours = air_time / 60,
              gain_per_hour = gain / hours) %>% head() #define new variables using existing variable
# Out:
#   year month day dep_delay arr_delay distance air_time gain hours
# 1 2013 1     1    2         11       1400     227       -9  3.783333
# 2 2013 1     1    4         20       1416     227      -16  3.783333
# 3 2013 1     1    2         33       1089     160      -31  2.666667
# 4 2013 1     1   -1        -18       1576     183       17  3.050000
# 5 2013 1     1   -6        -25        762     116       19  1.933333
# 6 2013 1     1   -4         12        719     150      -16  2.500000
#   gain_per_hour
# 1  -2.378855
# 2  -4.229075
# 3 -11.625000
# 4   5.573770
# 5   9.827586
# 6  -6.400000

# %% [markdown]
# ## summarise()
# #### : show grouped summaries

# %%
flights %>% group_by(year, month, day) %>%
summarise(delay = mean(dep_delay, na.rm = TRUE)) %>% head()
# Out:
# `summarise()` has grouped output by 'year', 'month'. You can override using the `.groups` argument.
#   year month day delay
# 1 2013 1     1   11.548926
# 2 2013 1     2   13.858824
# 3 2013 1     3   10.987832
# 4 2013 1     4    8.951595
# 5 2013 1     5    5.732218
# 6 2013 1     6    7.148014

# %% [markdown]
# ## Data visualization
# #### : ggplot

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy))
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
  geom_point()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy)) +
  geom_point() +
  geom_line()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, color = class)) + geom_point()
# Out:
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, size = class)) + geom_point() #size = class
# Out:
# Warning message:
# “Using size for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, alpha = class)) + geom_point() # alpha = class
# Out:
# Warning message:
# “Using alpha for a discrete variable is not advised.”
# plot without title

# %%
ggplot(data = mpg, mapping = aes(x = displ, y = hwy, shape = class)) + geom_point() # shape = class
# Out:
# Warning message:
# “The shape palette can deal with a maximum of 6 discrete values because
# more than 6 becomes difficult to discriminate; you have 7. Consider
# specifying shapes manually if you must have them.”
# Warning message:
# “Removed 62 rows containing missing values (geom_point).”
# plot without title

# %% [markdown]
# ## Facet

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes( x = displ, y =hwy)) +
  facet_wrap(~class, nrow = 2)                                    #facet_wrap
# Out:
# plot without title

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes( x = displ, y =hwy)) +
  facet_grid(drv ~ cyl)                                             #facet_grid
# Out:
# plot without title

# %% [markdown]
# ##Theme

# %%
ggplot(data = mpg) +
  geom_point(mapping = aes(x = displ, y = hwy)) + theme_bw() +
  theme(axis.line = element_line(size = 8, colour = "black"),
        panel.grid.minor = element_blank(),
        panel.border = element_blank().
        text = element_text(size = 25))
# Out:
# Error in parse(text = x, srcfile = src): <text>:5:39: unexpected symbol
# 4:         panel.grid.minor = element_blank(),
# 5:         panel.border = element_blank().
#                                          ^
# Traceback:
